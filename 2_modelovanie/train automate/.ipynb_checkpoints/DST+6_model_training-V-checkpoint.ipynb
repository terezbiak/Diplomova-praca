# %% [markdown]
# # Automatické tréningy pre rôzne n_input a horizonty (DST+1 … DST+6)
#
# Tento notebook načíta dáta **iba raz** a potom postupne vytvorí a natrénuje samostatný model pre každú kombináciu:
# - `n_input` ∈ {6, 12, 18, 24, 30, 36, 42, 48}
# - `y_col` = `DST+1` … `DST+6`
#
# Model/weighty sa ukladajú do `models/` a súhrn metrík do `results/summary.csv`.

# %%
import os
import numpy as np
import pandas as pd

from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Model
from keras.layers import Dense, Input, LSTM, Flatten, TimeDistributed, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Reprodukovateľnosť (voliteľné)
SEED = 42
np.random.seed(SEED)
keras.utils.set_random_seed(SEED)
# Out:
# 2026-04-11 21:09:00.331562: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os; 
print(os.getcwd())
# Out:
# /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/BP_Drengubiakova_Terezia/3_modelovanie/train automate

# %%
# =========================
# Nastavenia
# =========================

# Cesty k datasetom (ponechané ako v pôvodnom notebooku)
BASE_PATH = "/home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/BP_Drengubiakova_Terezia/0_datasety/"
file_path_train = BASE_PATH + "train_omni.csv"
file_path_test  = BASE_PATH + "test_omni.csv"


# Tréningové nastavenia
BATCH_SIZE = 256
EPOCHS = 200
PATIENCE = 25  # early stopping na val_mae

# Kombinácie na tréning
N_INPUT_LIST = [42, 48]
#N_INPUT_LIST = [6, 12, 18, 24, 30, 36, 42, 48]
HORIZONS = [6]

# Výstupné priečinky
MODELS_DIR = "models"
RESULTS_DIR = "results"
os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)

# %%
# =========================
# Načítanie dát (iba raz)
# =========================
train_raw = pd.read_csv(file_path_train)
test_raw  = pd.read_csv(file_path_test)

# Skontroluj, aké DST+ stĺpce existujú (pomôže odhaliť preklepy v názvoch)
dst_cols = [c for c in train_raw.columns if c.startswith("DST+")]
print("DST+ stĺpce v train:", dst_cols)
print("DST+ stĺpce v test :", [c for c in test_raw.columns if c.startswith("DST+")])

# čas
if "time1" in train_raw.columns:
    train_raw["time1"] = pd.to_datetime(train_raw["time1"])
if "time1" in test_raw.columns:
    test_raw["time1"] = pd.to_datetime(test_raw["time1"])
# Out:
# DST+ stĺpce v train: ['DST+1', 'DST+2', 'DST+3', 'DST+4', 'DST+5', 'DST+6']
# DST+ stĺpce v test : ['DST+1', 'DST+2', 'DST+3', 'DST+4', 'DST+5', 'DST+6']

# %%
def build_model(n_input: int, n_features: int) -> keras.Model:
    """LSTM model pre multivariačný vstup."""
    inputs = Input(shape=(n_input, n_features))

    x = Bidirectional(
        LSTM(128, return_sequences=True, dropout=0.1, recurrent_dropout=0.1)
    )(inputs)
    x = LSTM(128, return_sequences=True)(x)
    x = TimeDistributed(Dense(1, activation="linear"))(x)
    x = Flatten()(x)
    outputs = Dense(1, activation="linear")(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss="mse", optimizer="adam", metrics=["mae"])
    return model


def make_splits(train_df: pd.DataFrame, test_df: pd.DataFrame, y_col: str, predictors=None):
    """Pripraví train/valid/test dáta pre daný y_col (bez NaN)."""

    if predictors is None:
        predictors = ["DST", "v"]   

    features = predictors + [y_col]

    train = train_df[features].copy()
    test = test_df[features].copy()

    # odstránenie NaN
    train = train.dropna().reset_index(drop=True)
    test = test.dropna().reset_index(drop=True)

    # časový split train/valid
    valid_size = int(len(train) * 0.2)

    if valid_size == 0:
        raise ValueError(f"Príliš málo dát po dropna pre {y_col}")

    valid = train.iloc[-valid_size:, :].copy()
    train = train.iloc[:-valid_size, :].copy()

    # X = 2 features
    X_train = train[predictors].values
    y_train = train[y_col].values

    X_val = valid[predictors].values
    y_val = valid[y_col].values

    X_test = test[predictors].values
    y_test = test[y_col].values

    return (X_train, y_train), (X_val, y_val), (X_test, y_test), predictors

# %%
def train_one(y_col: str, n_input: int):
    predictors = ["DST", "v"]   

    (X_train, y_train), (X_val, y_val), (X_test, y_test), predictors = make_splits(
        train_raw, test_raw, y_col, predictors=predictors
    )

    train_gen = TimeseriesGenerator(X_train, y_train, length=n_input, batch_size=BATCH_SIZE)
    val_gen   = TimeseriesGenerator(X_val, y_val, length=n_input, batch_size=BATCH_SIZE)
    test_gen  = TimeseriesGenerator(X_test, y_test, length=n_input, batch_size=BATCH_SIZE)

    if len(train_gen) == 0 or len(val_gen) == 0:
        print(f"[SKIP] {y_col}, n_input={n_input} – prázdny generátor")
        return None

    n_features = len(predictors)
    model = build_model(n_input, n_features)

    print("Predictors:", predictors)
    print("X_train shape:", X_train.shape)
    print("First batch X shape:", train_gen[0][0].shape)
    print("Model input shape:", model.input_shape)

    model_path = os.path.join(MODELS_DIR, f"{y_col}_{n_input}H_V.keras")
    checkpoint = ModelCheckpoint(model_path, monitor="val_mae", verbose=1, save_best_only=True, mode="min")
    early = EarlyStopping(monitor="val_mae", mode="min", patience=PATIENCE, restore_best_weights=True)
    callbacks = [checkpoint, early]

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=EPOCHS,
        verbose=1,
        callbacks=callbacks
    )

    test_loss, test_mae = model.evaluate(test_gen, verbose=0)

    hist_df = pd.DataFrame(history.history)
    hist_csv = os.path.join(RESULTS_DIR, f"history_{y_col}_{n_input}H_V.csv")
    hist_df.to_csv(hist_csv, index=False)

    return {
        "y_col": y_col,
        "horizon_hours": int(y_col.split("+")[1]),
        "n_input": n_input,
        "best_val_mae": float(np.min(hist_df["val_mae"])) if "val_mae" in hist_df else np.nan,
        "best_val_loss": float(np.min(hist_df["val_loss"])) if "val_loss" in hist_df else np.nan,
        "test_mae": float(test_mae),
        "test_loss": float(test_loss),
        "model_path": model_path,
        "history_path": hist_csv,
        "epochs_ran": int(len(hist_df)),
    }

# %%
# =========================
# Spustenie všetkých tréningov
# =========================
summary_rows = []

for h in HORIZONS:
    y_col = f"DST+{h}"

    # ochrana, ak by stĺpec neexistoval
    if y_col not in train_raw.columns or y_col not in test_raw.columns:
        print(f"[SKIP] {y_col} neexistuje v datasete.")
        continue

    for n_input in N_INPUT_LIST:
        print("\n" + "="*80)
        print(f"Trénujem: y_col={y_col}, n_input={n_input}")
        print("="*80)

        row = train_one(y_col, n_input)
        if row is not None:
            summary_rows.append(row)


summary = pd.DataFrame(summary_rows)
summary_path = os.path.join(RESULTS_DIR, "summary6_V.csv")
summary.to_csv(summary_path, index=False)

summary.sort_values(["horizon_hours", "n_input"]).head(20), summary_path
# Out:
# ================================================================================
# Trénujem: y_col=DST+6, n_input=6
# ================================================================================
# Predictors: ['DST', 'v']
# X_train shape: (229356, 2)
# First batch X shape: (256, 6, 2)
# Model input shape: (None, 6, 2)
# Epoch 1/200
# /opt/conda/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 357.7599 - mae: 11.7572
# Epoch 1: val_mae improved from inf to 11.54260, saving model to models/DST+6_6H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 156s 156ms/step - loss: 357.6568 - mae: 11.7552 - val_loss: 390.7049 - val_mae: 11.5426
# Epoch 2/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 216.4221 - mae: 8.9750
# Epoch 2: val_mae improved from 11.54260 to 10.02142, saving model to models/DST+6_6H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 139s 155ms/step - loss: 216.3884 - mae: 8.9745 - val_loss: 309.6109 - val_mae: 10.0214
# Epoch 3/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss:
saving model to models/DST+6_24H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 487s 521ms/step - loss: 335.2492 - mae: 11.5442 - val_loss: 349.2230 - val_mae: 10.8512
# Epoch 2/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - loss: 197.2173 - mae: 8.9136
# Epoch 2: val_mae improved from 10.85125 to 10.25863, saving model to models/DST+6_24H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 449s 501ms/step - loss: 197.2271 - mae: 8.9137 - val_loss: 308.4881 - val_mae: 10.2586
# Epoch 3/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - loss: 180.7424 - mae: 8.4867
# Epoch 3: val_mae improved from 10.25863 to 9.72512, saving model to models/DST+6_24H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 439s 490ms/step - loss: 180.7551 - mae: 8.4869 - val_loss: 290.8645 - val_mae: 9.7251
# Epoch 4/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 170.8781 - mae: 8.2654
# Epoch 4: val_mae did not improve from 9.72512
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 444s 496ms/step - loss: 170.8904 - mae: 8.2656 - val_loss: 326.5498 - val_mae: 10.4853
# Epoch 5/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - loss: 207.5973 - mae: 8.8490
# Epoch 5: val_mae improved from 9.72512 to 9.57913, saving model to models/DST+6_24H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 440s 491ms/step - loss: 207.5625 - mae: 8.8484 - val_loss: 288.3339 - val_mae: 9.5791
# Epoch 6/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - loss: 171.9613 - mae: 8.1636
# Epoch 6: val_mae improved from 9.57913 to 9.43026, saving model to models/DST+6_24H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 440s 491ms/step - loss: 171.9621 - mae: 8.1637 - val_loss: 270.2982 - val_mae: 9.4303
# Epoch 7/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - loss: 167.4719 - mae: 8.1366
# Epoch 7: val_mae did not improve from 9.43026
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 443s 494ms/step - loss: 167.4744 - mae: 8.1367 - val_loss: 306.2824 - val_mae: 10.1059
# Epoch 8/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - loss: 165.5942 - mae: 8.1530
# Epoch 8: val_mae did not improve from 9.43026
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 443s 495ms/step - loss: 165.5972 - mae: 8.1530 - val_loss: 299.5752 - val_mae: 9.8958
# Epoch 9/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - loss: 170.3649 - mae: 8.1692
# Epoch 9: val_mae did not improve from 9.43026
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 444s 495ms/step - loss: 170.3610 - mae: 8.1692 - val_loss: 260.5633 - val_mae: 9.4570
# Epoch 10/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 161.3963 - mae: 7.9896
# Epoch 10: val_mae did not improve from 9.43026
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 440s 491ms/step - loss: 161.4019 - mae: 7.9897 - val_loss: 281.0796 - val_mae: 9.7873
# Epoch 11/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - loss: 171.7029 - mae: 8.2512
# Epoch 11: val_mae did not improve from 9.43026
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 448s 500ms/step - loss: 171.6936 - mae: 8.2509 - val_loss: 271.3582 - val_mae: 10.4587
# Epoch 12/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - loss: 165.4955 - mae: 8.1018
# Epoch 12: val_mae did not improve from 9.43026
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 446s 498ms/step - loss: 165.4916 - mae: 8.1017 - val_loss: 275.4994 - val_mae: 9.5912
# Epoch 13/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - loss: 153.4685 - mae: 7.8559
# Epoch 13: val_mae improved from 9.43026 to 9.31278, saving model to models/DST+6_24H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 452s 504ms/step - loss: 153.4766 - mae: 7.8560 - val_loss: 248.1669 - val_mae: 9.3128
# Epoch 14/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - loss: 159.4375 - mae: 7.9233
# Epoch 14: val_mae did not improve from 9.31278
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 447s 499ms/step - loss: 159.4371 - mae: 7.9233 - val_loss: 246.3954 - val_mae: 9.4610
# Epoch 15/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - loss: 164.1782 - mae: 7.9910
# Epoch 15: val_mae did not improve from 9.31278
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 453s 506ms/step - loss: 164.1717 - mae: 7.9909 - val_loss: 296.3628 - val_mae: 10.1449
# Epoch 16/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - loss: 148.4484 - mae: 7.7942
# Epoch 16: val_mae did not improve from 9.31278
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 443s 494ms/step - loss: 148.4613 - mae: 7.7944 - val_loss: 265.3359 - val_mae: 9.5185
# Epoch 17/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - loss: 165.0685 - mae: 7.9803
# Epoch 17: val_mae improved from 9.31278 to 9.29394, saving model to models/DST+6_24H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 451s 503ms/step - loss: 165.0601 - mae: 7.9803 - val_loss: 260.4736 - val_mae: 9.2939
# Epoch 18/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - loss: 144.0801 - mae: 7.6798
# Epoch 18: val_mae did not improve from 9.29394
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 451s 503ms/step - loss:
val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 437s 487ms/step - loss: 155.6886 - mae: 7.7463 - val_loss: 254.0012 - val_mae: 9.4589
# Epoch 55/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - loss: 139.5982 - mae: 7.5597
# Epoch 55: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 396s 442ms/step - loss: 139.5993 - mae: 7.5597 - val_loss: 248.5312 - val_mae: 9.1602
# Epoch 56/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - loss: 133.7339 - mae: 7.4280
# Epoch 56: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 396s 442ms/step - loss: 133.7427 - mae: 7.4281 - val_loss: 252.6910 - val_mae: 9.2562
# Epoch 57/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - loss: 141.2952 - mae: 7.6080
# Epoch 57: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 410s 457ms/step - loss: 141.2953 - mae: 7.6079 - val_loss: 240.4608 - val_mae: 9.3314
# Epoch 58/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 140.7762 - mae: 7.5238
# Epoch 58: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 415s 463ms/step - loss: 140.7763 - mae: 7.5238 - val_loss: 266.6996 - val_mae: 9.6607
# Epoch 59/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 139.7345 - mae: 7.5178
# Epoch 59: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 416s 464ms/step - loss: 139.7353 - mae: 7.5178 - val_loss: 250.2692 - val_mae: 9.3703
# Epoch 60/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - loss: 142.3732 - mae: 7.5519
# Epoch 60: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 419s 467ms/step - loss: 142.3703 - mae: 7.5519 - val_loss: 227.6574 - val_mae: 8.9532
# Epoch 61/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 130.1537 - mae: 7.4088
# Epoch 61: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 417s 465ms/step - loss: 130.1663 - mae: 7.4090 - val_loss: 262.4738 - val_mae: 9.4845
# Epoch 62/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - loss: 142.9157 - mae: 7.6338
# Epoch 62: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 452s 476ms/step - loss: 142.9120 - mae: 7.6336 - val_loss: 232.7728 - val_mae: 8.9859
# Epoch 63/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - loss: 138.6564 - mae: 7.5383
# Epoch 63: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 428s 478ms/step - loss: 138.6581 - mae: 7.5383 - val_loss: 237.5964 - val_mae: 9.0349
# Epoch 64/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - loss: 142.5559 - mae: 7.5524
# Epoch 64: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 425s 474ms/step - loss: 142.5534 - mae: 7.5524 - val_loss: 238.5240 - val_mae: 9.1119
# Epoch 65/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - loss: 135.8839 - mae: 7.4901
# Epoch 65: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 420s 468ms/step - loss: 135.8873 - mae: 7.4901 - val_loss: 269.0531 - val_mae: 9.7854
# Epoch 66/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - loss: 143.4276 - mae: 7.6306
# Epoch 66: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 418s 467ms/step - loss: 143.4233 - mae: 7.6305 - val_loss: 252.7687 - val_mae: 9.5408
# Epoch 67/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - loss: 137.6940 - mae: 7.5219
# Epoch 67: val_mae did not improve from 8.90378
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 414s 461ms/step - loss: 137.6951 - mae: 7.5219 - val_loss: 266.7456 - val_mae: 9.7904
#
# ================================================================================
# Trénujem: y_col=DST+6, n_input=30
# ================================================================================
# Predictors: ['DST', 'v']
# X_train shape: (229356, 2)
# First batch X shape: (256, 30, 2)
# Model input shape: (None, 30, 2)
# Epoch 1/200
# /opt/conda/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 188/896 ━━━━━━━━━━━━━━━━━━━━ 5:04 430ms/step - loss: 426.9380 - mae: 14.3251

# %% [markdown]
# ## Poznámky
# - Ak chceš presne poradie ako si písala (najprv `DST+1` pre všetky `n_input`, potom `DST+2`, …), tak to presne robí horný loop (horizonty vonkajší, `n_input` vnútorný).
# - Ak chceš opačne (pre dané `n_input` spraviť `DST+1..6`), stačí prehodiť poradie cyklov.
