# %% [markdown]
# # Automatické tréningy pre rôzne n_input a horizonty (DST+1 … DST+6)
#
# Tento notebook načíta dáta **iba raz** a potom postupne vytvorí a natrénuje samostatný model pre každú kombináciu:
# - `n_input` ∈ {6, 12, 18, 24, 30, 36, 42, 48}
# - `y_col` = `DST+1` … `DST+6`
#
# Model/weighty sa ukladajú do `models/` a súhrn metrík do `results/summary.csv`.

# %%
import os
import numpy as np
import pandas as pd

from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Model
from keras.layers import Dense, Input, LSTM, Flatten, TimeDistributed, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Reprodukovateľnosť (voliteľné)
SEED = 42
np.random.seed(SEED)
keras.utils.set_random_seed(SEED)
# Out:
# 2026-04-13 14:23:31.658040: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os; 
print(os.getcwd())
# Out:
# /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/BP_Drengubiakova_Terezia/3_modelovanie/train automate

# %%
# =========================
# Nastavenia
# =========================

# Cesty k datasetom (ponechané ako v pôvodnom notebooku)
BASE_PATH = "/home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/BP_Drengubiakova_Terezia/0_datasety/"
file_path_train = BASE_PATH + "train_omni.csv"
file_path_test  = BASE_PATH + "test_omni.csv"


# Tréningové nastavenia
BATCH_SIZE = 256
EPOCHS = 200
PATIENCE = 25  # early stopping na val_mae

# Kombinácie na tréning
N_INPUT_LIST = [36, 42, 48]
#N_INPUT_LIST = [6, 12, 18, 24, 30, 36, 42, 48]
HORIZONS = [4]

# Výstupné priečinky
MODELS_DIR = "models"
RESULTS_DIR = "results"
os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)

# %%
# =========================
# Načítanie dát (iba raz)
# =========================
train_raw = pd.read_csv(file_path_train)
test_raw  = pd.read_csv(file_path_test)

# Skontroluj, aké DST+ stĺpce existujú (pomôže odhaliť preklepy v názvoch)
dst_cols = [c for c in train_raw.columns if c.startswith("DST+")]
print("DST+ stĺpce v train:", dst_cols)
print("DST+ stĺpce v test :", [c for c in test_raw.columns if c.startswith("DST+")])

# čas
if "time1" in train_raw.columns:
    train_raw["time1"] = pd.to_datetime(train_raw["time1"])
if "time1" in test_raw.columns:
    test_raw["time1"] = pd.to_datetime(test_raw["time1"])
# Out:
# DST+ stĺpce v train: ['DST+1', 'DST+2', 'DST+3', 'DST+4', 'DST+5', 'DST+6']
# DST+ stĺpce v test : ['DST+1', 'DST+2', 'DST+3', 'DST+4', 'DST+5', 'DST+6']

# %%
def build_model(n_input: int, n_features: int) -> keras.Model:
    """LSTM model pre multivariačný vstup."""
    inputs = Input(shape=(n_input, n_features))

    x = Bidirectional(
        LSTM(128, return_sequences=True, dropout=0.1, recurrent_dropout=0.1)
    )(inputs)
    x = LSTM(128, return_sequences=True)(x)
    x = TimeDistributed(Dense(1, activation="linear"))(x)
    x = Flatten()(x)
    outputs = Dense(1, activation="linear")(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss="mse", optimizer="adam", metrics=["mae"])
    return model


def make_splits(train_df: pd.DataFrame, test_df: pd.DataFrame, y_col: str, predictors=None):
    """Pripraví train/valid/test dáta pre daný y_col (bez NaN)."""

    if predictors is None:
        predictors = ["DST", "v"]   

    features = predictors + [y_col]

    train = train_df[features].copy()
    test = test_df[features].copy()

    # odstránenie NaN
    train = train.dropna().reset_index(drop=True)
    test = test.dropna().reset_index(drop=True)

    # časový split train/valid
    valid_size = int(len(train) * 0.2)

    if valid_size == 0:
        raise ValueError(f"Príliš málo dát po dropna pre {y_col}")

    valid = train.iloc[-valid_size:, :].copy()
    train = train.iloc[:-valid_size, :].copy()

    # X = 2 features
    X_train = train[predictors].values
    y_train = train[y_col].values

    X_val = valid[predictors].values
    y_val = valid[y_col].values

    X_test = test[predictors].values
    y_test = test[y_col].values

    return (X_train, y_train), (X_val, y_val), (X_test, y_test), predictors

# %%
def train_one(y_col: str, n_input: int):
    predictors = ["DST", "v"]   

    (X_train, y_train), (X_val, y_val), (X_test, y_test), predictors = make_splits(
        train_raw, test_raw, y_col, predictors=predictors
    )

    train_gen = TimeseriesGenerator(X_train, y_train, length=n_input, batch_size=BATCH_SIZE)
    val_gen   = TimeseriesGenerator(X_val, y_val, length=n_input, batch_size=BATCH_SIZE)
    test_gen  = TimeseriesGenerator(X_test, y_test, length=n_input, batch_size=BATCH_SIZE)

    if len(train_gen) == 0 or len(val_gen) == 0:
        print(f"[SKIP] {y_col}, n_input={n_input} – prázdny generátor")
        return None

    n_features = len(predictors)
    model = build_model(n_input, n_features)

    print("Predictors:", predictors)
    print("X_train shape:", X_train.shape)
    print("First batch X shape:", train_gen[0][0].shape)
    print("Model input shape:", model.input_shape)

    model_path = os.path.join(MODELS_DIR, f"{y_col}_{n_input}H_V.keras")
    checkpoint = ModelCheckpoint(model_path, monitor="val_mae", verbose=1, save_best_only=True, mode="min")
    early = EarlyStopping(monitor="val_mae", mode="min", patience=PATIENCE, restore_best_weights=True)
    callbacks = [checkpoint, early]

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=EPOCHS,
        verbose=1,
        callbacks=callbacks
    )

    test_loss, test_mae = model.evaluate(test_gen, verbose=0)

    hist_df = pd.DataFrame(history.history)
    hist_csv = os.path.join(RESULTS_DIR, f"history_{y_col}_{n_input}H_V.csv")
    hist_df.to_csv(hist_csv, index=False)

    return {
        "y_col": y_col,
        "horizon_hours": int(y_col.split("+")[1]),
        "n_input": n_input,
        "best_val_mae": float(np.min(hist_df["val_mae"])) if "val_mae" in hist_df else np.nan,
        "best_val_loss": float(np.min(hist_df["val_loss"])) if "val_loss" in hist_df else np.nan,
        "test_mae": float(test_mae),
        "test_loss": float(test_loss),
        "model_path": model_path,
        "history_path": hist_csv,
        "epochs_ran": int(len(hist_df)),
    }

# %%
# =========================
# Spustenie všetkých tréningov
# =========================
summary_rows = []

for h in HORIZONS:
    y_col = f"DST+{h}"

    # ochrana, ak by stĺpec neexistoval
    if y_col not in train_raw.columns or y_col not in test_raw.columns:
        print(f"[SKIP] {y_col} neexistuje v datasete.")
        continue

    for n_input in N_INPUT_LIST:
        print("\n" + "="*80)
        print(f"Trénujem: y_col={y_col}, n_input={n_input}")
        print("="*80)

        row = train_one(y_col, n_input)
        if row is not None:
            summary_rows.append(row)


summary = pd.DataFrame(summary_rows)
summary_path = os.path.join(RESULTS_DIR, "summary4_V.csv")
summary.to_csv(summary_path, index=False)

summary.sort_values(["horizon_hours", "n_input"]).head(20), summary_path
# Out:
# ================================================================================
# Trénujem: y_col=DST+4, n_input=36
# ================================================================================
# Predictors: ['DST', 'v']
# X_train shape: (229356, 2)
# First batch X shape: (256, 36, 2)
# Model input shape: (None, 36, 2)
# Epoch 1/200
# /opt/conda/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 352.9208 - mae: 12.1333
# Epoch 1: val_mae improved from inf to 11.34892, saving model to models/DST+4_36H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 537s 590ms/step - loss: 352.8185 - mae: 12.1311 - val_loss: 352.7854 - val_mae: 11.3489
# Epoch 2/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 184.8251 - mae: 8.5223
# Epoch 2: val_mae improved from 11.34892 to 9.59820, saving model to models/DST+4_36H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 522s 583ms/step - loss: 184.8022 - mae: 8.5217 - val_loss: 261.5769 - val_mae: 9.5982
# Epoch 3/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 157.6143 - mae: 7.9410
# Epoch 3: val_mae improved from 9.59820 to 8.55419, saving model to models/DST+4_36H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 524s 585ms/step - loss: 157.6049 - mae: 7.9407 - val_loss: 219.1673 - val_mae: 8.5542
# Epoch 4/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - loss: 146.7544 - mae: 7.5849
# Epoch 4: val_mae improved from 8.55419 to 8.40136, saving model to models/DST+4_36H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 531s 593ms/step - loss: 146.7468 - mae: 7.5848 - val_loss: 220.4330 - val_mae: 8.4014
# Epoch 5/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 136.2291 - mae: 7.3545
# Epoch 5: val_mae improved from 8.40136 to 8.09647, saving model to models/DST+4_36H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 534s 597ms/step - loss: 136.2243 - mae: 7.3544 - val_loss: 183.3032 - val_mae: 8.0965
# Epoch 6/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 129.5772 - mae: 7.2934
# Epoch 6: val_mae did not improve from 8.09647
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 530s 592ms/step - loss: 129.5816 - mae: 7.2934 - val_loss: 211.3164 - val_mae: 8.3303
# Epoch 7/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - loss: 121.4244 - mae: 6.9128
# Epoch 7: val_mae did not improve from 8.09647
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 530s 592ms/step - loss: 121.4301 - mae: 6.9130 - val_loss: 196.2811 - val_mae: 8.1975
# Epoch 8/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - loss: 117.2007 - mae: 6.9328
# Epoch 8: val_mae did not improve from 8.09647
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 537s 600ms/step - loss: 117.2067 - mae: 6.9329 - val_loss: 232.2699 - val_mae: 9.0023
# Epoch 9/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 118.0963 - mae: 6.9528
# Epoch 9: val_mae did not improve from 8.09647
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 533s 595ms/step - loss: 118.0979 - mae: 6.9528 - val_loss: 174.6207 - val_mae: 8.2745
# Epoch 10/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 119.3196 - mae: 6.9695
# Epoch 10: val_mae improved from 8.09647 to 8.00211, saving model to models/DST+4_36H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 525s 586ms/step - loss: 119.3202 - mae: 6.9695 - val_loss: 183.4513 - val_mae: 8.0021
# Epoch 11/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 109.7101 - mae: 6.7933
# Epoch 11: val_mae did not improve from 8.00211
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 563s 629ms/step - loss: 109.7167 - mae: 6.7933 - val_loss: 198.1151 - val_mae: 8.2145
# Epoch 12/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - loss: 116.4153 - mae: 6.9148
# Epoch 12: val_mae did not improve from 8.00211
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 526s 587ms/step - loss: 116.4151 - mae: 6.9148 - val_loss: 210.3857 - val_mae: 8.5136
# Epoch 13/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 118.7646 - mae: 6.9178
# Epoch 13: val_mae did not improve from 8.00211
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 570s 637ms/step - loss: 118.7595 - mae: 6.9177 - val_loss: 199.5424 - val_mae: 8.2375
# Epoch 14/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 112.6386 - mae: 6.7530
# Epoch 14: val_mae did not improve from 8.00211
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 522s 583ms/step - loss: 112.6399 - mae: 6.7530 - val_loss: 185.0220 - val_mae: 8.0645
# Epoch 15/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 108.4612 - mae: 6.7493
# Epoch 15: val_mae did not improve from 8.00211
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 524s 585ms/step - loss: 108.4657 - mae: 6.7493 - val_loss: 188.1195 - val_mae: 8.3761
# Epoch 16/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 106.1384 - mae: 6.7163
# Epoch 16: val_mae improved from 8.00211 to 7.75723, saving model to models/DST+4_36H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 537s 599ms/step - loss: 106.1450 - mae: 6.7163 - val_loss: 169.9868 - val_mae: 7.7572
# Epoch 17/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - loss: 104.9822 - mae: 6.6090
# Epoch 17: val_mae did not improve from 7.75723
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 539s 601ms/step - loss: 104.9864 - mae: 6.6091 - val_loss: 202.9509 - val_mae: 8.4644
# Epoch 18/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 106.3575 - mae: 6.6567
# Epoch 18: val_mae did not improve from 7.75723
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 529s 590ms/step - loss: 106.3617 - mae: 6.6568 - val_loss: 201.2171 - val_mae: 8.3460
# Epoch 19/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - loss: 116.4084 - mae: 6.8629
# Epoch 19: val_mae improved from 7.75723 to 7.67942, saving model to models/DST+4_36H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 516s 576ms/step - loss: 116.3988 - mae: 6.8627 - val_loss: 162.4402 - val_mae: 7.6794
# Epoch 20/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 113.4884 - mae: 6.8193
# Epoch 20: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 518s 578ms/step - loss: 113.4850 - mae: 6.8192 - val_loss: 187.0561 - val_mae: 8.0384
# Epoch 21/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 106.7767 - mae: 6.7073
# Epoch 21: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 532s 594ms/step - loss: 106.7771 - mae: 6.7073 - val_loss: 174.1923 - val_mae: 7.9141
# Epoch 22/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 108.3996 - mae: 6.7157
# Epoch 22: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 525s 586ms/step - loss: 108.3994 - mae: 6.7156 - val_loss: 184.4395 - val_mae: 8.0511
# Epoch 23/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 110.2406 - mae: 6.7992
# Epoch 23: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 531s 592ms/step - loss: 110.2379 - mae: 6.7991 - val_loss: 161.6303 - val_mae: 7.6828
# Epoch 24/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 108.5157 - mae: 6.6809
# Epoch 24: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 524s 585ms/step - loss: 108.5151 - mae: 6.6809 - val_loss: 171.8507 - val_mae: 7.7553
# Epoch 25/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 100.5676 - mae: 6.5745
# Epoch 25: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 566s 631ms/step - loss: 100.5738 - mae: 6.5745 - val_loss: 160.5961 - val_mae: 7.9115
# Epoch 26/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 115.6421 - mae: 6.8147
# Epoch 26: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 584s 589ms/step - loss: 115.6325 - mae: 6.8145 - val_loss: 170.6573 - val_mae: 7.9426
# Epoch 27/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 105.6455 - mae: 6.6504
# Epoch 27: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 525s 586ms/step - loss: 105.6462 - mae: 6.6504 - val_loss: 177.3803 - val_mae: 7.9782
# Epoch 28/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 111.5133 - mae: 6.7344
# Epoch 28: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 523s 584ms/step - loss: 111.5061 - mae: 6.7342 - val_loss: 172.2129 - val_mae: 7.8887
# Epoch 29/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - loss: 102.6572 - mae: 6.5364
# Epoch 29: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 535s 598ms/step - loss: 102.6606 - mae: 6.5365 - val_loss: 174.1516 - val_mae: 7.9644
# Epoch 30/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - loss: 103.8428 - mae: 6.5500
# Epoch 30: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 534s 596ms/step - loss: 103.8451 - mae: 6.5501 - val_loss: 185.7276 - val_mae: 7.9504
# Epoch 31/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 101.2626 - mae: 6.5692
# Epoch 31: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 527s 588ms/step - loss: 101.2667 - mae: 6.5693 - val_loss: 188.2513 - val_mae: 8.2925
# Epoch 32/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 106.1916 - mae: 6.6695
# Epoch 32: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 533s 594ms/step - loss: 106.1888 - mae: 6.6695 - val_loss: 217.1066 - val_mae: 8.5564
# Epoch 33/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 100.2465 - mae: 6.5522
# Epoch 33: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 535s 598ms/step - loss: 100.2538 - mae: 6.5523 - val_loss: 186.0433 - val_mae: 8.0106
# Epoch 34/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 101.2295 - mae: 6.5317
# Epoch 34: val_mae did not improve from 7.67942
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 535s 597ms/step - loss: 101.2350 - mae: 6.5318 - val_loss: 179.2749 - val_mae: 8.1771
# Epoch 35/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 99.5992 - mae: 6.5436
# Epoch 35: val_mae improved from 7.67942 to 7.61298, saving model to models/DST+4_36H_V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 526s 587ms/step - loss: 99.6050 - mae: 6.5437 - val_loss: 154.8212 - val_mae: 7.6130
# Epoch 36/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 104.3099 - mae: 6.5581
# Epoch 36: val_mae did not improve from 7.61298
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 531s 592ms/step - loss: 104.3094 - mae: 6.5581 - val_loss: 169.6098 - val_mae: 7.9727
# Epoch 37/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 104.6550 - mae: 6.5876
# Epoch 37: val_mae did not improve from 7.61298
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 535s 597ms/step - loss: 104.6551 - mae: 6.5876 - val_loss: 176.2060 - val_mae: 8.1049
# Epoch 38/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 115.5735 - mae: 6.6926
# Epoch 38: val_mae did not improve from 7.61298
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 534s 596ms/step - loss: 115.5611 - mae: 6.6925 - val_loss: 168.2597 - val_mae: 7.8617
# Epoch 39/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 108.2459 - mae: 6.6134
# Epoch 39: val_mae did not improve from 7.61298
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 532s 594ms/step - loss: 108.2410 - mae: 6.6134 - val_loss: 210.4412 - val_mae: 8.7505
# Epoch 40/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 110.2420 - mae: 6.7093
# Epoch 40: val_mae did not improve from 7.61298
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 510s 569ms/step - loss: 110.2373 - mae: 6.7092 - val_loss: 174.1867 - val_mae: 7.9075
# Epoch 41/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 104.5645 - mae: 6.5585
# Epoch 41: val_mae did not improve from 7.61298
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 524s 585ms/step - loss: 104.5622 - mae: 6.5585 - val_loss: 183.4224 - val_mae: 8.3555
# Epoch 42/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 102.8292 - mae: 6.5640
# Epoch 42: val_mae did not improve from 7.61298
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 528s 589ms/step - loss: 102.8306 - mae: 6.5640 - val_loss: 187.9886 - val_mae: 8.2229
# Epoch 43/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 110.5843 - mae: 6.7281
# Epoch 43: val_mae did not improve from 7.61298
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 528s 589ms/step - loss: 110.5752 - mae: 6.7279 - val_loss: 173.2409 - val_mae: 7.8830
# Epoch 44/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 102.2366 - mae: 6.4968
# Epoch 44: val_mae did not improve from 7.61298
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 527s 588ms/step - loss: 102.2376 - mae: 6.4969 - val_loss: 170.3900 - val_mae: 7.7645
# Epoch 45/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - loss: 104.2538 - mae: 6.5814
# Epoch 45: val_mae did not improve from 7.61298
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 532s 593ms/step - loss: 104.2519 - mae: 6.5814 - val_loss: 167.7199 - val_mae: 7.7269
# Epoch 46/200
# 850/896 ━━━━━━━━━━━━━━━━━━━━ 25s 552ms/step - loss: 103.1250 - mae: 6.5532
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - loss: 140.0569 - mae: 7.4524
# Epoch 6: val_mae did not improve from 8.38603
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 390s 436ms/step - loss: 140.0519 - mae: 7.4523 - val_loss: 231.0516 - val_mae: 8.8581
# Epoch 7/200
# 337/896 ━━━━━━━━━━━━━━━━━━━━ 3:49 410ms/step - loss: 144.3290 - mae: 7.3528

# %% [markdown]
# ## Poznámky
# - Ak chceš presne poradie ako si písala (najprv `DST+1` pre všetky `n_input`, potom `DST+2`, …), tak to presne robí horný loop (horizonty vonkajší, `n_input` vnútorný).
# - Ak chceš opačne (pre dané `n_input` spraviť `DST+1..6`), stačí prehodiť poradie cyklov.
