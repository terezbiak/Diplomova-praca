# %% [markdown]
# # Automatické tréningy pre rôzne n_input a horizonty (DST+1 … DST+6)
#
# Tento notebook načíta dáta **iba raz** a potom postupne vytvorí a natrénuje samostatný model pre každú kombináciu:
# - `n_input` ∈ {6, 12, 18, 24, 30, 36, 42, 48}
# - `y_col` = `DST+1` … `DST+6`
#
# Model/weighty sa ukladajú do `models/` a súhrn metrík do `results/summary.csv`.

# %%
import os
import numpy as np
import pandas as pd

from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Model
from keras.layers import Dense, Input, LSTM, Flatten, TimeDistributed, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Reprodukovateľnosť (voliteľné)
SEED = 42
np.random.seed(SEED)
keras.utils.set_random_seed(SEED)
# Out:
# 2026-03-05 12:00:19.267081: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os; 
print(os.getcwd())
# Out:
# /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/BP_Drengubiakova_Terezia/3_modelovanie/train automate

# %%
# =========================
# Nastavenia
# =========================

# Cesty k datasetom (ponechané ako v pôvodnom notebooku)
BASE_PATH = "/home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/BP_Drengubiakova_Terezia/0_datasety/"
file_path_train = BASE_PATH + "train_omni.csv"
file_path_test  = BASE_PATH + "test_omni.csv"


# Tréningové nastavenia
BATCH_SIZE = 256
EPOCHS = 200
PATIENCE = 25  # early stopping na val_mae

# Kombinácie na tréning
#N_INPUT_LIST = [6, 12, 18, 24, 30, 36, 42, 48]
N_INPUT_LIST = [48]
HORIZONS = [1]

# Výstupné priečinky
MODELS_DIR = "models_3atr"
RESULTS_DIR = "results"
os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)

# %%
# =========================
# Načítanie dát (iba raz)
# =========================
train_raw = pd.read_csv(file_path_train)
test_raw  = pd.read_csv(file_path_test)

# Skontroluj, aké DST+ stĺpce existujú (pomôže odhaliť preklepy v názvoch)
dst_cols = [c for c in train_raw.columns if c.startswith("DST+")]
print("DST+ stĺpce v train:", dst_cols)
print("DST+ stĺpce v test :", [c for c in test_raw.columns if c.startswith("DST+")])

# čas
if "time1" in train_raw.columns:
    train_raw["time1"] = pd.to_datetime(train_raw["time1"])
if "time1" in test_raw.columns:
    test_raw["time1"] = pd.to_datetime(test_raw["time1"])
# Out:
# DST+ stĺpce v train: ['DST+1', 'DST+2', 'DST+3', 'DST+4', 'DST+5', 'DST+6']
# DST+ stĺpce v test : ['DST+1', 'DST+2', 'DST+3', 'DST+4', 'DST+5', 'DST+6']

# %%
train_raw
# Out:
#         Unnamed: 0.1  Unnamed: 0                     time1  bz_gsm      v  \
# 0                  0           0 1963-01-01 00:30:00+00:00    -0.2  285.0
# 1                  1           1 1963-01-01 01:30:00+00:00    -0.2  285.0
# 2                  2           2 1963-01-01 02:30:00+00:00    -0.2  285.0
# 3                  3           3 1963-01-01 03:30:00+00:00    -0.2  285.0
# 4                  4           4 1963-01-01 04:30:00+00:00    -0.2  285.0
# ...              ...         ...                       ...     ...    ...
# 286690        286690      286690 1995-09-15 10:30:00+00:00    -5.6  429.0
# 286691        286691      286691 1995-09-15 11:30:00+00:00    -2.9  435.0
# 286692        286692      286692 1995-09-15 12:30:00+00:00    -7.8  440.0
# 286693        286693      286693 1995-09-15 13:30:00+00:00    -5.6  440.0
# 286694        286694      286694 1995-09-15 14:30:00+00:00    -4.3  442.0
#
#         DST  DST+1  DST+2  DST+3  DST+4  DST+5  DST+6
# 0        -6     -6   -5.0   -5.0   -3.0   -3.0   -6.0
# 1        -5     -5   -5.0   -3.0   -3.0   -6.0   -8.0
# 2        -5     -5   -3.0   -3.0   -6.0   -8.0   -9.0
# 3        -3     -3   -3.0   -6.0   -8.0   -9.0   -6.0
# 4        -3     -3   -6.0   -8.0   -9.0   -6.0   -2.0
# ...     ...    ...    ...    ...    ...    ...    ...
# 286690  -52    -52  -48.0  -40.0  -39.0  -45.0  -48.0
# 286691  -48    -48  -40.0  -39.0  -45.0  -48.0  -45.0
# 286692  -40    -40  -39.0  -45.0  -48.0  -45.0  -41.0
# 286693  -39    -39  -45.0  -48.0  -45.0  -41.0  -41.0
# 286694  -45    -45  -48.0  -45.0  -41.0  -41.0  -34.0
#
# [286695 rows x 12 columns]

# %%
def build_model(n_input: int) -> keras.Model:
    """Architektúra z pôvodného notebooku."""
    inputs = Input(shape=(n_input, 3))
    x = Bidirectional(LSTM(128, return_sequences=True, dropout=0.1, recurrent_dropout=0.1))(inputs)
    x = LSTM(128, return_sequences=True)(x)
    x = TimeDistributed(Dense(1, activation="linear"))(x)
    x = Flatten()(x)
    outputs = Dense(1, activation="linear")(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss="mse", optimizer="adam", metrics=["mae"])
    return model


def make_splits(train_df: pd.DataFrame, test_df: pd.DataFrame, y_col: str):
    """Pripraví train/valid/test dáta pre daný y_col (bez NaN)."""

    x_cols = ["DST", "bz_gsm", "v"]
    features = x_cols + [y_col]

    train = train_df[features].copy()
    test  = test_df[features].copy()

    # odstránenie NaN spôsobených DST+X
    train = train.dropna().reset_index(drop=True)
    test  = test.dropna().reset_index(drop=True)

    # časový split train/valid
    valid_size = int(len(train) * 0.2)
    if valid_size == 0:
        raise ValueError(f"Príliš málo dát po dropna pre {y_col}")

    valid = train.iloc[-valid_size:, :].copy()
    train = train.iloc[:-valid_size, :].copy()

    # X musí byť 2D: (počet_riadkov, 3)
    X_train = train[x_cols].values
    y_train = train[y_col].values

    X_val = valid[x_cols].values
    y_val = valid[y_col].values

    X_test = test[x_cols].values
    y_test = test[y_col].values

    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# %%
def train_one(y_col: str, n_input: int):
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = make_splits(train_raw, test_raw, y_col)

    train_gen = TimeseriesGenerator(X_train, y_train, length=n_input, batch_size=BATCH_SIZE)
    val_gen   = TimeseriesGenerator(X_val, y_val, length=n_input, batch_size=BATCH_SIZE)
    test_gen  = TimeseriesGenerator(X_test, y_test, length=n_input, batch_size=BATCH_SIZE)

    if len(train_gen) == 0 or len(val_gen) == 0:
        print(f"[SKIP] {y_col}, n_input={n_input} – prázdny generátor")
        return None

    
    model = build_model(n_input)

    model_path = os.path.join(MODELS_DIR, f"{y_col}_{n_input}H_BZ+V.keras")
    checkpoint = ModelCheckpoint(model_path, monitor="val_mae", verbose=1, save_best_only=True, mode="min")
    early = EarlyStopping(monitor="val_mae", mode="min", patience=PATIENCE, restore_best_weights=True)
    callbacks = [checkpoint, early]

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=EPOCHS,
        verbose=1,
        callbacks=callbacks
    )

    # finálne vyhodnotenie na test sete
    test_loss, test_mae = model.evaluate(test_gen, verbose=0)

    # uložiť aj history (voliteľné)
    hist_df = pd.DataFrame(history.history)
    hist_csv = os.path.join(RESULTS_DIR, f"history_{y_col}_{n_input}H_BZ+V.csv")
    hist_df.to_csv(hist_csv, index=False)

    return {
        "y_col": y_col,
        "horizon_hours": int(y_col.split("+")[1]),
        "n_input": n_input,
        "best_val_mae": float(np.min(hist_df["val_mae"])) if "val_mae" in hist_df else np.nan,
        "best_val_loss": float(np.min(hist_df["val_loss"])) if "val_loss" in hist_df else np.nan,
        "test_mae": float(test_mae),
        "test_loss": float(test_loss),
        "model_path": model_path,
        "history_path": hist_csv,
        "epochs_ran": int(len(hist_df)),
    }

# %%
# =========================
# Spustenie všetkých tréningov
# =========================
summary_rows = []

for h in HORIZONS:
    y_col = f"DST+{h}"

    # ochrana, ak by stĺpec neexistoval
    if y_col not in train_raw.columns or y_col not in test_raw.columns:
        print(f"[SKIP] {y_col} neexistuje v datasete.")
        continue

    for n_input in N_INPUT_LIST:
        print("\n" + "="*80)
        print(f"Trénujem: y_col={y_col}, n_input={n_input}")
        print("="*80)

        row = train_one(y_col, n_input)
        if row is not None:
            summary_rows.append(row)


summary = pd.DataFrame(summary_rows)
summary_path = os.path.join(RESULTS_DIR, "summary_1_BZ+V.csv")
summary.to_csv(summary_path, index=False)

summary.sort_values(["horizon_hours", "n_input"]).head(20), summary_path
# Out:
# ================================================================================
# Trénujem: y_col=DST+1, n_input=48
# ================================================================================
# Epoch 1/200
# /opt/conda/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 975ms/step - loss: 446.4413 - mae: 14.1650
# Epoch 1: val_mae improved from inf to 9.01385, saving model to models_3atr/DST+1_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 965s 1s/step - loss: 446.3078 - mae: 14.1621 - val_loss: 251.3188 - val_mae: 9.0139
# Epoch 2/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 130.1408 - mae: 6.8025
# Epoch 2: val_mae improved from 9.01385 to 5.68752, saving model to models_3atr/DST+1_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1016s 1s/step - loss: 130.1134 - mae: 6.8019 - val_loss: 133.8644 - val_mae: 5.6875
# Epoch 3/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 82.5798 - mae: 5.5455
# Epoch 3: val_mae improved from 5.68752 to 4.98303, saving model to models_3atr/DST+1_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1046s 1s/step - loss: 82.5756 - mae: 5.5455 - val_loss: 93.3757 - val_mae: 4.9830
# Epoch 4/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss:
val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1036s 1s/step - loss: 23.5899 - mae: 3.1520 - val_loss: 48.0715 - val_mae: 4.2732
# Epoch 42/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 20.6654 - mae: 2.9751
# Epoch 42: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1045s 1s/step - loss: 20.6664 - mae: 2.9751 - val_loss: 48.1295 - val_mae: 4.0303
# Epoch 43/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 22.3199 - mae: 3.0555
# Epoch 43: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1045s 1s/step - loss: 22.3181 - mae: 3.0554 - val_loss: 49.5789 - val_mae: 4.3493
# Epoch 44/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 23.0414 - mae: 3.0387
# Epoch 44: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1053s 1s/step - loss: 23.0402 - mae: 3.0387 - val_loss: 57.3651 - val_mae: 4.4448
# Epoch 45/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 20.8370 - mae: 2.9557
# Epoch 45: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1055s 1s/step - loss: 20.8370 - mae: 2.9557 - val_loss: 40.6576 - val_mae: 3.7067
# Epoch 46/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 21.5340 - mae: 3.0212
# Epoch 46: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 21.5333 - mae: 3.0212 - val_loss: 38.6821 - val_mae: 3.8626
# Epoch 47/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 20.6369 - mae: 2.9461
# Epoch 47: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1051s 1s/step - loss: 20.6369 - mae: 2.9461 - val_loss: 48.5631 - val_mae: 4.4954
# Epoch 48/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 20.0561 - mae: 2.9449
# Epoch 48: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1056s 1s/step - loss: 20.0562 - mae: 2.9449 - val_loss: 58.0908 - val_mae: 4.5871
# Epoch 49/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 20.5523 - mae: 2.9268
# Epoch 49: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1046s 1s/step - loss: 20.5517 - mae: 2.9268 - val_loss: 73.2988 - val_mae: 5.6682
# Epoch 50/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 25.1127 - mae: 3.1546
# Epoch 50: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1044s 1s/step - loss: 25.1101 - mae: 3.1545 - val_loss: 48.0061 - val_mae: 4.3619
# Epoch 51/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 20.3372 - mae: 2.9643
# Epoch 51: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1059s 1s/step - loss: 20.3380 - mae: 2.9643 - val_loss: 40.0006 - val_mae: 3.9575
# Epoch 52/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 22.8922 - mae: 3.0743
# Epoch 52: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1081s 1s/step - loss: 22.8904 - mae: 3.0742 - val_loss: 46.1275 - val_mae: 3.8212
# Epoch 53/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 21.0214 - mae: 3.0089
# Epoch 53: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1021s 1s/step - loss: 21.0206 - mae: 3.0089 - val_loss: 47.2004 - val_mae: 4.2508
# Epoch 54/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 21.1223 - mae: 3.0159
# Epoch 54: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1078s 1s/step - loss: 21.1228 - mae: 3.0159 - val_loss: 57.9184 - val_mae: 4.6961
# Epoch 55/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 24.7059 - mae: 3.0737
# Epoch 55: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1093s 1s/step - loss: 24.7014 - mae: 3.0736 - val_loss: 45.1168 - val_mae: 4.0594
# Epoch 56/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 20.6524 - mae: 2.9453
# Epoch 56: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1066s 1s/step - loss: 20.6535 - mae: 2.9453 - val_loss: 46.5665 - val_mae: 3.9489
# Epoch 57/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 21.0058 - mae: 2.9870
# Epoch 57: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1061s 1s/step - loss: 21.0056 - mae: 2.9870 - val_loss: 46.4135 - val_mae: 4.1304
# Epoch 58/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 20.4329 - mae: 2.9779
# Epoch 58: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1053s 1s/step - loss: 20.4332 - mae: 2.9779 - val_loss: 45.6537 - val_mae: 4.3333
# Epoch 59/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 19.8804 - mae: 2.9041
# Epoch 59: val_mae did not improve from 3.58476
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1070s 1s/step - loss: 19.8802 - mae: 2.9041 - val_loss: 43.2633 - val_mae: 3.9835
# (   y_col  horizon_hours  n_input  best_val_mae  best_val_loss  test_mae  \
#  0  DST+1              1       48      3.584757      36.627567  2.355071
#
#     test_loss                        model_path  \
#  0  12.923867  models_3atr/DST+1_48H_BZ+V.keras
#
#                           history_path  epochs_ran
#  0  results/history_DST+1_48H_BZ+V.csv          59  ,
#  'results/summary_1_BZ+V.csv')

# %% [markdown]
# ## Poznámky
# - Ak chceš presne poradie ako si písala (najprv `DST+1` pre všetky `n_input`, potom `DST+2`, …), tak to presne robí horný loop (horizonty vonkajší, `n_input` vnútorný).
# - Ak chceš opačne (pre dané `n_input` spraviť `DST+1..6`), stačí prehodiť poradie cyklov.
