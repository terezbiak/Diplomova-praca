# %% [markdown]
# # Automatické tréningy pre rôzne n_input a horizonty (DST+1 … DST+6)
#
# Tento notebook načíta dáta **iba raz** a potom postupne vytvorí a natrénuje samostatný model pre každú kombináciu:
# - `n_input` ∈ {6, 12, 18, 24, 30, 36, 42, 48}
# - `y_col` = `DST+1` … `DST+6`
#
# Model/weighty sa ukladajú do `models/` a súhrn metrík do `results/summary.csv`.

# %%
import os
import numpy as np
import pandas as pd

from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Model
from keras.layers import Dense, Input, LSTM, Flatten, TimeDistributed, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Reprodukovateľnosť (voliteľné)
SEED = 42
np.random.seed(SEED)
keras.utils.set_random_seed(SEED)
# Out:
# 2026-03-05 12:00:44.026910: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os; 
print(os.getcwd())
# Out:
# /home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/BP_Drengubiakova_Terezia/3_modelovanie/train automate

# %%
# =========================
# Nastavenia
# =========================

# Cesty k datasetom (ponechané ako v pôvodnom notebooku)
BASE_PATH = "/home/jovyan/data/lightning/TereziaD/DP_pokracovanieBP/BP_Drengubiakova_Terezia/0_datasety/"
file_path_train = BASE_PATH + "train_omni.csv"
file_path_test  = BASE_PATH + "test_omni.csv"


# Tréningové nastavenia
BATCH_SIZE = 256
EPOCHS = 200
PATIENCE = 25  # early stopping na val_mae

# Kombinácie na tréning
#N_INPUT_LIST = [6, 12, 18, 24, 30, 36, 42, 48]
N_INPUT_LIST = [48]
HORIZONS = [2]

# Výstupné priečinky
MODELS_DIR = "models_3atr"
RESULTS_DIR = "results"
os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)

# %%
# =========================
# Načítanie dát (iba raz)
# =========================
train_raw = pd.read_csv(file_path_train)
test_raw  = pd.read_csv(file_path_test)

# Skontroluj, aké DST+ stĺpce existujú (pomôže odhaliť preklepy v názvoch)
dst_cols = [c for c in train_raw.columns if c.startswith("DST+")]
print("DST+ stĺpce v train:", dst_cols)
print("DST+ stĺpce v test :", [c for c in test_raw.columns if c.startswith("DST+")])

# čas
if "time1" in train_raw.columns:
    train_raw["time1"] = pd.to_datetime(train_raw["time1"])
if "time1" in test_raw.columns:
    test_raw["time1"] = pd.to_datetime(test_raw["time1"])
# Out:
# DST+ stĺpce v train: ['DST+1', 'DST+2', 'DST+3', 'DST+4', 'DST+5', 'DST+6']
# DST+ stĺpce v test : ['DST+1', 'DST+2', 'DST+3', 'DST+4', 'DST+5', 'DST+6']

# %%
train_raw
# Out:
#         Unnamed: 0.1  Unnamed: 0                     time1  bz_gsm      v  \
# 0                  0           0 1963-01-01 00:30:00+00:00    -0.2  285.0
# 1                  1           1 1963-01-01 01:30:00+00:00    -0.2  285.0
# 2                  2           2 1963-01-01 02:30:00+00:00    -0.2  285.0
# 3                  3           3 1963-01-01 03:30:00+00:00    -0.2  285.0
# 4                  4           4 1963-01-01 04:30:00+00:00    -0.2  285.0
# ...              ...         ...                       ...     ...    ...
# 286690        286690      286690 1995-09-15 10:30:00+00:00    -5.6  429.0
# 286691        286691      286691 1995-09-15 11:30:00+00:00    -2.9  435.0
# 286692        286692      286692 1995-09-15 12:30:00+00:00    -7.8  440.0
# 286693        286693      286693 1995-09-15 13:30:00+00:00    -5.6  440.0
# 286694        286694      286694 1995-09-15 14:30:00+00:00    -4.3  442.0
#
#         DST  DST+1  DST+2  DST+3  DST+4  DST+5  DST+6
# 0        -6     -6   -5.0   -5.0   -3.0   -3.0   -6.0
# 1        -5     -5   -5.0   -3.0   -3.0   -6.0   -8.0
# 2        -5     -5   -3.0   -3.0   -6.0   -8.0   -9.0
# 3        -3     -3   -3.0   -6.0   -8.0   -9.0   -6.0
# 4        -3     -3   -6.0   -8.0   -9.0   -6.0   -2.0
# ...     ...    ...    ...    ...    ...    ...    ...
# 286690  -52    -52  -48.0  -40.0  -39.0  -45.0  -48.0
# 286691  -48    -48  -40.0  -39.0  -45.0  -48.0  -45.0
# 286692  -40    -40  -39.0  -45.0  -48.0  -45.0  -41.0
# 286693  -39    -39  -45.0  -48.0  -45.0  -41.0  -41.0
# 286694  -45    -45  -48.0  -45.0  -41.0  -41.0  -34.0
#
# [286695 rows x 12 columns]

# %%
def build_model(n_input: int) -> keras.Model:
    """Architektúra z pôvodného notebooku."""
    inputs = Input(shape=(n_input, 3))
    x = Bidirectional(LSTM(128, return_sequences=True, dropout=0.1, recurrent_dropout=0.1))(inputs)
    x = LSTM(128, return_sequences=True)(x)
    x = TimeDistributed(Dense(1, activation="linear"))(x)
    x = Flatten()(x)
    outputs = Dense(1, activation="linear")(x)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss="mse", optimizer="adam", metrics=["mae"])
    return model


def make_splits(train_df: pd.DataFrame, test_df: pd.DataFrame, y_col: str):
    """Pripraví train/valid/test dáta pre daný y_col (bez NaN)."""

    x_cols = ["DST", "bz_gsm", "v"]
    features = x_cols + [y_col]

    train = train_df[features].copy()
    test  = test_df[features].copy()

    # odstránenie NaN spôsobených DST+X
    train = train.dropna().reset_index(drop=True)
    test  = test.dropna().reset_index(drop=True)

    # časový split train/valid
    valid_size = int(len(train) * 0.2)
    if valid_size == 0:
        raise ValueError(f"Príliš málo dát po dropna pre {y_col}")

    valid = train.iloc[-valid_size:, :].copy()
    train = train.iloc[:-valid_size, :].copy()

    # X musí byť 2D: (počet_riadkov, 3)
    X_train = train[x_cols].values
    y_train = train[y_col].values

    X_val = valid[x_cols].values
    y_val = valid[y_col].values

    X_test = test[x_cols].values
    y_test = test[y_col].values

    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# %%
def train_one(y_col: str, n_input: int):
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = make_splits(train_raw, test_raw, y_col)

    train_gen = TimeseriesGenerator(X_train, y_train, length=n_input, batch_size=BATCH_SIZE)
    val_gen   = TimeseriesGenerator(X_val, y_val, length=n_input, batch_size=BATCH_SIZE)
    test_gen  = TimeseriesGenerator(X_test, y_test, length=n_input, batch_size=BATCH_SIZE)

    if len(train_gen) == 0 or len(val_gen) == 0:
        print(f"[SKIP] {y_col}, n_input={n_input} – prázdny generátor")
        return None

    
    model = build_model(n_input)

    model_path = os.path.join(MODELS_DIR, f"{y_col}_{n_input}H_BZ+V.keras")
    checkpoint = ModelCheckpoint(model_path, monitor="val_mae", verbose=1, save_best_only=True, mode="min")
    early = EarlyStopping(monitor="val_mae", mode="min", patience=PATIENCE, restore_best_weights=True)
    callbacks = [checkpoint, early]

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=EPOCHS,
        verbose=1,
        callbacks=callbacks
    )

    # finálne vyhodnotenie na test sete
    test_loss, test_mae = model.evaluate(test_gen, verbose=0)

    # uložiť aj history (voliteľné)
    hist_df = pd.DataFrame(history.history)
    hist_csv = os.path.join(RESULTS_DIR, f"history_{y_col}_{n_input}H_BZ+V.csv")
    hist_df.to_csv(hist_csv, index=False)

    return {
        "y_col": y_col,
        "horizon_hours": int(y_col.split("+")[1]),
        "n_input": n_input,
        "best_val_mae": float(np.min(hist_df["val_mae"])) if "val_mae" in hist_df else np.nan,
        "best_val_loss": float(np.min(hist_df["val_loss"])) if "val_loss" in hist_df else np.nan,
        "test_mae": float(test_mae),
        "test_loss": float(test_loss),
        "model_path": model_path,
        "history_path": hist_csv,
        "epochs_ran": int(len(hist_df)),
    }

# %%
# =========================
# Spustenie všetkých tréningov
# =========================
summary_rows = []

for h in HORIZONS:
    y_col = f"DST+{h}"

    # ochrana, ak by stĺpec neexistoval
    if y_col not in train_raw.columns or y_col not in test_raw.columns:
        print(f"[SKIP] {y_col} neexistuje v datasete.")
        continue

    for n_input in N_INPUT_LIST:
        print("\n" + "="*80)
        print(f"Trénujem: y_col={y_col}, n_input={n_input}")
        print("="*80)

        row = train_one(y_col, n_input)
        if row is not None:
            summary_rows.append(row)


summary = pd.DataFrame(summary_rows)
summary_path = os.path.join(RESULTS_DIR, "summary_2_BZ+V.csv")
summary.to_csv(summary_path, index=False)

summary.sort_values(["horizon_hours", "n_input"]).head(20), summary_path
# Out:
# ================================================================================
# Trénujem: y_col=DST+2, n_input=48
# ================================================================================
# Epoch 1/200
# /opt/conda/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 988ms/step - loss: 455.7973 - mae: 14.3981
# Epoch 1: val_mae improved from inf to 9.79465, saving model to models_3atr/DST+2_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 979s 1s/step - loss: 455.6806 - mae: 14.3956 - val_loss: 308.3317 - val_mae: 9.7947
# Epoch 2/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 168.3955 - mae: 8.0094
# Epoch 2: val_mae improved from 9.79465 to 7.18415, saving model to models_3atr/DST+2_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 983s 1s/step - loss: 168.3668 - mae: 8.0088 - val_loss: 172.5038 - val_mae: 7.1841
# Epoch 3/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 121.3643 - mae: 6.9509
# Epoch 3: val_mae improved from 7.18415 to 6.71901, saving model to models_3atr/DST+2_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 992s 1s/step - loss: 121.3537 - mae: 6.9506 - val_loss: 142.9094 - val_mae: 6.7190
# Epoch 4/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 99.3879 - mae: 6.2790
# Epoch 4: val_mae did not improve from 6.71901
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 981s 1s/step - loss: 99.3820 - mae: 6.2788 - val_loss: 153.4255 - val_mae: 6.7201
# Epoch 5/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 97.9022 - mae: 6.2795
# Epoch 5: val_mae improved from 6.71901 to 6.66884, saving model to models_3atr/DST+2_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 992s 1s/step - loss: 97.8951 - mae: 6.2793 - val_loss: 122.7659 - val_mae: 6.6688
# Epoch 6/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 78.4657 - mae: 5.7784
# Epoch 6: val_mae improved from 6.66884 to 6.43768, saving model to models_3atr/DST+2_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1006s 1s/step - loss: 78.4705 - mae: 5.7784 - val_loss: 132.7870 - val_mae: 6.4377
# Epoch 7/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 76.9775 - mae: 5.5451
# Epoch 7: val_mae did not improve from 6.43768
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 995s 1s/step - loss: 76.9813 - mae: 5.5453 - val_loss: 138.2238 - val_mae: 6.6432
# Epoch 8/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 70.6081 - mae: 5.4366
# Epoch 8: val_mae did not improve from 6.43768
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 977s 1s/step - loss: 70.6121 - mae: 5.4367 - val_loss: 119.9923 - val_mae: 6.7049
# Epoch 9/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 66.9336 - mae: 5.3438
# Epoch 9: val_mae improved from 6.43768 to 6.14836, saving model to models_3atr/DST+2_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 988s 1s/step - loss: 66.9369 - mae: 5.3439 - val_loss: 102.3108 - val_mae: 6.1484
# Epoch 10/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 65.1184 - mae: 5.2263
# Epoch 10: val_mae improved from 6.14836 to 5.95993, saving model to models_3atr/DST+2_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 997s 1s/step - loss: 65.1189 - mae: 5.2263 - val_loss: 104.2432 - val_mae: 5.9599
# Epoch 11/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 60.7138 - mae: 5.1057
# Epoch 11: val_mae did not improve from 5.95993
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 990s 1s/step - loss: 60.7167 - mae: 5.1058 - val_loss: 108.9877 - val_mae: 6.0120
# Epoch 12/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 59.4101 - mae: 5.0101
# Epoch 12: val_mae did not improve from 5.95993
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 59.4121 - mae: 5.0101 - val_loss: 111.3655 - val_mae: 6.2000
# Epoch 13/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 61.3369 - mae: 5.0724
# Epoch 13: val_mae did not improve from 5.95993
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1004s 1s/step - loss: 61.3362 - mae: 5.0724 - val_loss: 116.0835 - val_mae: 6.2717
# Epoch 14/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 60.8556 - mae: 5.0463
# Epoch 14: val_mae improved from 5.95993 to 5.86093, saving model to models_3atr/DST+2_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1003s 1s/step - loss: 60.8539 - mae: 5.0463 - val_loss: 102.0046 - val_mae: 5.8609
# Epoch 15/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 52.6746 - mae: 4.7692
# Epoch 15: val_mae improved from 5.86093 to 5.74841, saving model to models_3atr/DST+2_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1009s 1s/step - loss: 52.6766 - mae: 4.7692 - val_loss: 89.9569 - val_mae: 5.7484
# Epoch 16/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 51.8283 - mae: 4.7700
# Epoch 16: val_mae improved from 5.74841 to 5.56997, saving model to models_3atr/DST+2_48H_BZ+V.keras
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1008s 1s/step - loss: 51.8320 - mae: 4.7701 - val_loss: 86.3255 - val_mae: 5.5700
# Epoch 17/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 53.4295 - mae: 4.7830
# Epoch 17: val_mae did not improve from 5.56997
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1036s 1s/step - loss: 53.4295 - mae: 4.7830 - val_loss: 102.8351 - val_mae: 6.1728
# Epoch 18/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 53.3764 - mae: 4.8041
# Epoch 18: val_mae did not improve from 5.56997
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 
val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1065s 1s/step - loss: 50.3599 - mae: 4.5930 - val_loss: 92.3369 - val_mae: 6.0803
# Epoch 56/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 47.1797 - mae: 4.5533
# Epoch 56: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1068s 1s/step - loss: 47.1810 - mae: 4.5533 - val_loss: 78.6339 - val_mae: 5.3885
# Epoch 57/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 47.2618 - mae: 4.5493
# Epoch 57: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1053s 1s/step - loss: 47.2612 - mae: 4.5492 - val_loss: 93.0435 - val_mae: 5.8503
# Epoch 58/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 47.9487 - mae: 4.5839
# Epoch 58: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1036s 1s/step - loss: 47.9497 - mae: 4.5839 - val_loss: 80.5907 - val_mae: 5.5429
# Epoch 59/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 47.1963 - mae: 4.5506
# Epoch 59: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1080s 1s/step - loss: 47.1959 - mae: 4.5505 - val_loss: 79.4384 - val_mae: 5.5484
# Epoch 60/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 47.1805 - mae: 4.5378
# Epoch 60: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1007s 1s/step - loss: 47.1797 - mae: 4.5378 - val_loss: 103.7073 - val_mae: 6.4799
# Epoch 61/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 46.7084 - mae: 4.5602
# Epoch 61: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1005s 1s/step - loss: 46.7081 - mae: 4.5602 - val_loss: 79.6329 - val_mae: 5.3820
# Epoch 62/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 47.6006 - mae: 4.5875
# Epoch 62: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1009s 1s/step - loss: 47.5994 - mae: 4.5874 - val_loss: 79.2011 - val_mae: 5.6707
# Epoch 63/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 49.2253 - mae: 4.6061
# Epoch 63: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 999s 1s/step - loss: 49.2223 - mae: 4.6060 - val_loss: 82.2721 - val_mae: 5.6122
# Epoch 64/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 48.7685 - mae: 4.6018
# Epoch 64: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 985s 1s/step - loss: 48.7665 - mae: 4.6017 - val_loss: 91.2752 - val_mae: 6.1784
# Epoch 65/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 47.5004 - mae: 4.5427
# Epoch 65: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1011s 1s/step - loss: 47.4998 - mae: 4.5427 - val_loss: 98.4143 - val_mae: 6.3189
# Epoch 66/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 44.4939 - mae: 4.4929
# Epoch 66: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1055s 1s/step - loss: 44.4956 - mae: 4.4929 - val_loss: 85.0424 - val_mae: 5.6826
# Epoch 67/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 43.4608 - mae: 4.4572
# Epoch 67: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1071s 1s/step - loss: 43.4634 - mae: 4.4572 - val_loss: 87.0662 - val_mae: 5.8114
# Epoch 68/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 53.4819 - mae: 4.7229
# Epoch 68: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1026s 1s/step - loss: 53.4775 - mae: 4.7227 - val_loss: 89.7384 - val_mae: 5.8117
# Epoch 69/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 43.6339 - mae: 4.4256
# Epoch 69: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1021s 1s/step - loss: 43.6370 - mae: 4.4257 - val_loss: 89.5978 - val_mae: 5.6871
# Epoch 70/200
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 47.7293 - mae: 4.5527
# Epoch 70: val_mae did not improve from 5.37045
# 896/896 ━━━━━━━━━━━━━━━━━━━━ 1017s 1s/step - loss: 47.7271 - mae: 4.5526 - val_loss: 87.9047 - val_mae: 5.7166
# (   y_col  horizon_hours  n_input  best_val_mae  best_val_loss  test_mae  \
#  0  DST+2              2       48      5.370447      75.992897  3.674305
#
#     test_loss                        model_path  \
#  0  31.296156  models_3atr/DST+2_48H_BZ+V.keras
#
#                           history_path  epochs_ran
#  0  results/history_DST+2_48H_BZ+V.csv          70  ,
#  'results/summary_2_BZ+V.csv')

# %% [markdown]
# ## Poznámky
# - Ak chceš presne poradie ako si písala (najprv `DST+1` pre všetky `n_input`, potom `DST+2`, …), tak to presne robí horný loop (horizonty vonkajší, `n_input` vnútorný).
# - Ak chceš opačne (pre dané `n_input` spraviť `DST+1..6`), stačí prehodiť poradie cyklov.
