# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import layers, Model
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# 2026-02-22 19:34:20.958346: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Foldy presne podľa štúdie (Table 2)
FOLDS = {
    1: {"val": [4, 21, 11], "test": [8, 14, 28]},
    2: {"val": [22, 19, 28], "test": [25, 21, 1]},
    3: {"val": [4, 31, 1], "test": [34, 15, 28]},
    4: {"val": [7, 15, 13], "test": [35, 21, 1]},
    5: {"val": [7, 21, 29], "test": [35, 19, 23]},
}

def split_by_fold(df_events: pd.DataFrame, fold: int):
    spec = FOLDS[fold]
    val_events = set(spec["val"])
    test_events = set(spec["test"])
    train_events = set(df_events["event_no"].unique()) - val_events - test_events

    train = df_events[df_events["event_no"].isin(train_events)].copy()
    val   = df_events[df_events["event_no"].isin(val_events)].copy()
    test  = df_events[df_events["event_no"].isin(test_events)].copy()

    return train, val, test, sorted(train_events), sorted(val_events), sorted(test_events)

# %%
def make_sequences_eventwise(df_part, feature_cols, target_col="DST", L=24, H=4):
    """
    Vytvorí (X, y, t) z df_part, ale vždy zvlášť v rámci event_no.
    X: (N, L, n_features), y: (N,), t: timestamp cieľa (Dst v čase t+H)
    """
    X_list, y_list, t_list, ev_list = [], [], [], []

    for ev, g in df_part.groupby("event_no"):
        g = g.sort_index()
        data = g[feature_cols + [target_col]].to_numpy(dtype=np.float32)
        times = g.index.to_numpy(dtype="datetime64[ns]")

        # index i = koniec vstupného okna (posledný vstup je i-1), cieľ je i-1+H
        # vstupné okno: [i-L, i)
        for i in range(L, len(g) - H + 1):
            x = data[i-L:i, :len(feature_cols)]
            y = data[i-1+H, len(feature_cols)]  # target_col
            t = times[i-1+H]
            X_list.append(x)
            y_list.append(y)
            t_list.append(t)
            ev_list.append(ev)

    X = np.stack(X_list) if X_list else np.empty((0, L, len(feature_cols)), dtype=np.float32)
    y = np.array(y_list, dtype=np.float32)
    t = np.array(t_list)
    ev = np.array(ev_list)
    return X, y, t, ev

def fit_scalers_on_train(X_train, y_train):
    # škálujeme feature-y (na poslednej osi) a target y
    n_feat = X_train.shape[-1]
    x_scaler = StandardScaler()
    y_scaler = StandardScaler()

    X2 = X_train.reshape(-1, n_feat)
    x_scaler.fit(X2)

    y_scaler.fit(y_train.reshape(-1, 1))
    return x_scaler, y_scaler

def transform_Xy(X, y, x_scaler, y_scaler):
    n_feat = X.shape[-1]
    Xs = x_scaler.transform(X.reshape(-1, n_feat)).reshape(X.shape).astype(np.float32)
    ys = y_scaler.transform(y.reshape(-1, 1)).reshape(-1).astype(np.float32)
    return Xs, ys

# %%
def build_lstm_model(L, n_feat, hidden=64, dropout=0.2):
    inp = layers.Input(shape=(L, n_feat), name="x")
    x = layers.LSTM(hidden, return_sequences=False, name="lstm")(inp)
    x = layers.Dropout(dropout)(x)
    emb = layers.Dense(hidden, activation="relu", name="emb")(x)
    out = layers.Dense(1, name="y")(emb)

    model = Model(inp, out)
    emb_model = Model(inp, emb)  # na extrakciu embeddingu

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss=tf.keras.losses.Huber(delta=1.0),
        metrics=[tf.keras.metrics.MeanAbsoluteError()]
    )
    return model, emb_model

# %%
def fit_gp_on_residuals(emb_train, y_true_s, y_pred_s):
    # reziduá v škálovanom y priestore
    r = (y_true_s - y_pred_s).reshape(-1, 1)

    # kernel: RBF + šum
    kernel = 1.0 * RBF(length_scale=1.0) + WhiteKernel(noise_level=1e-3)
    gp = GaussianProcessRegressor(kernel=kernel, normalize_y=True, random_state=0)
    gp.fit(emb_train, r.ravel())
    return gp

# %%
def evaluate_intervals(y_true, y_mean, y_std, alpha=0.05):
    # normálne intervaly: mean ± z * std
    # 90% => z=1.645, 95% => z=1.96
    z = 1.645 if alpha == 0.10 else 1.96
    lo = y_mean - z * y_std
    hi = y_mean + z * y_std
    coverage = np.mean((y_true >= lo) & (y_true <= hi))
    width = np.mean(hi - lo)
    return coverage, width

def train_lstm_gp_for_fold(df_events, fold=1, feature_cols=("dst","v","bz_gsm"), target_col="dst",
                           L=24, H=4, hidden=64, dropout=0.2, epochs=50, batch_size=256):
    train_df, val_df, test_df, tr_ev, va_ev, te_ev = split_by_fold(df_events, fold)
    if not isinstance(df_events.index, pd.DatetimeIndex):
        raise ValueError("df_events musí mať DatetimeIndex (nastav cez df.set_index('time1')).")
    # sequences
    Xtr, ytr, ttr, evtr = make_sequences_eventwise(train_df, list(feature_cols), target_col, L, H)
    Xva, yva, tva, evva = make_sequences_eventwise(val_df,   list(feature_cols), target_col, L, H)
    Xte, yte, tte, evte = make_sequences_eventwise(test_df,  list(feature_cols), target_col, L, H)

    if len(Xtr) == 0 or len(Xva) == 0 or len(Xte) == 0:
        raise ValueError("Niektorá split sada nemá dostatok dát na tvorbu okien. Skontroluj L/H alebo dáta.")

    # scaling (len train!)
    x_scaler, y_scaler = fit_scalers_on_train(Xtr, ytr)
    Xtr_s, ytr_s = transform_Xy(Xtr, ytr, x_scaler, y_scaler)
    Xva_s, yva_s = transform_Xy(Xva, yva, x_scaler, y_scaler)
    Xte_s, yte_s = transform_Xy(Xte, yte, x_scaler, y_scaler)

    # model
    model, emb_model = build_lstm_model(L, n_feat=Xtr_s.shape[-1], hidden=hidden, dropout=dropout)

    callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=4, min_lr=1e-5),
    ]

    model.fit(
        Xtr_s, ytr_s,
        validation_data=(Xva_s, yva_s),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=1
    )

    # LSTM preds (scaled)
    ytr_pred_s = model.predict(Xtr_s, batch_size=1024).reshape(-1)
    yte_pred_s = model.predict(Xte_s, batch_size=1024).reshape(-1)

    # embeddings
    emb_tr = emb_model.predict(Xtr_s, batch_size=1024)
    emb_te = emb_model.predict(Xte_s, batch_size=1024)

    # GP on residuals (scaled space)
    gp = fit_gp_on_residuals(emb_tr, ytr_s, ytr_pred_s)

    # GP predict residual mean/std (scaled)
    r_mu_s, r_std_s = gp.predict(emb_te, return_std=True)
    r_std_s = r_std_s.reshape(-1)

    # combined prediction (scaled): y_hat = lstm + gp_mean_resid
    yhat_s = yte_pred_s + r_mu_s

    # prepočet späť do nT
    yhat = y_scaler.inverse_transform(yhat_s.reshape(-1,1)).reshape(-1)
    ytrue = yte
    # std v nT: keď y = a*ys + b, tak std_y = a*std_ys, kde a = y_scaler.scale_
    a = float(y_scaler.scale_[0])
    ystd = a * r_std_s  # len neistota reziduí; LSTM bodová zložka je deterministická

    # metrics
    mse = mean_squared_error(ytrue, yhat)
    rmse = float(np.sqrt(mse))
    mae = mean_absolute_error(ytrue, yhat)

    cov90, w90 = evaluate_intervals(ytrue, yhat, ystd, alpha=0.10)
    cov95, w95 = evaluate_intervals(ytrue, yhat, ystd, alpha=0.05)

    results = {
        "fold": fold,
        "train_events": tr_ev, "val_events": va_ev, "test_events": te_ev,
        "N_train": len(ytr), "N_val": len(yva), "N_test": len(yte),
        "RMSE_nT": rmse,
        "MAE_nT": mae,
        "PICP_90": cov90, "MPIW_90_nT": w90,
        "PICP_95": cov95, "MPIW_95_nT": w95,
    }

    artifacts = {
        "model": model,
        "emb_model": emb_model,
        "gp": gp,
        "x_scaler": x_scaler,
        "y_scaler": y_scaler,
        "test_pred": pd.DataFrame({
            "time": pd.to_datetime(tte),
            "event_no": evte,
            "DST_true": ytrue,
            "DST_pred": yhat,
            "sigma_nT": ystd
        }).set_index("time").sort_index()
    }

    return results, artifacts

# %%
df_events = pd.read_csv("../../0_datasety/events_omni.csv")

# parse time a nastav ako index
df_events["time1"] = pd.to_datetime(df_events["time1"], utc=True)
df_events = df_events.set_index("time1").sort_index()

# voliteľne: nech je event_no int
df_events["event_no"] = df_events["event_no"].astype(int)

df_events.head()
# Out:
#                            bz_gsm      v  dst  event_no
# time1
# 1998-04-24 05:30:00+00:00    -6.7  444.0  -56         1
# 1998-04-24 06:30:00+00:00    -6.9  442.0  -59         1
# 1998-04-24 07:30:00+00:00    -4.4  435.0  -69         1
# 1998-04-24 08:30:00+00:00    -1.5  437.0  -50         1
# 1998-04-24 09:30:00+00:00    -4.0  452.0  -38         1

# %%
# df_events musí obsahovať: index datetime UTC + stĺpce DST,V,BZ_GSM + event_no
res1, art1 = train_lstm_gp_for_fold(df_events, fold=1, L=24, H=4)
print(res1)
art1["test_pred"].head()
# Out:
# Epoch 1/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.1845 - mean_absolute_error: 0.4191 - val_loss: 0.1022 - val_mean_absolute_error: 0.2717 - learning_rate: 0.0010
# Epoch 2/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0960 - mean_absolute_error: 0.2734 - val_loss: 0.0885 - val_mean_absolute_error: 0.2511 - learning_rate: 0.0010
# Epoch 3/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0828 - mean_absolute_error: 0.2519 - val_loss: 0.0840 - val_mean_absolute_error: 0.2408 - learning_rate: 0.0010
# Epoch 4/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0863 - mean_absolute_error: 0.2559 - val_loss: 0.0808 - val_mean_absolute_error: 0.2344 - learning_rate: 0.0010
# Epoch 5/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0816 - mean_absolute_error: 0.2483 - val_loss: 0.0811 - val_mean_absolute_error: 0.2398 - learning_rate: 0.0010
# Epoch 6/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0742 - mean_absolute_error: 0.2403 - val_loss: 0.0785 - val_mean_absolute_error: 0.2292 - learning_rate: 0.0010
# Epoch 7/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0712 - mean_absolute_error: 0.2351 - val_loss: 0.0771 - val_mean_absolute_error: 0.2329 - learning_rate: 0.0010
# Epoch 8/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0733 - mean_absolute_error: 0.2367 - val_loss: 0.0769 - val_mean_absolute_error: 0.2300 - learning_rate: 0.0010
# Epoch 9/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0719 - mean_absolute_error: 0.2318 - val_loss: 0.0767 - val_mean_absolute_error: 0.2345 - learning_rate: 0.0010
# Epoch 10/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0742 - mean_absolute_error: 0.2355 - val_loss: 0.0746 - val_mean_absolute_error: 0.2233 - learning_rate: 0.0010
# Epoch 11/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0671 - mean_absolute_error: 0.2270 - val_loss: 0.0745 - val_mean_absolute_error: 0.2245 - learning_rate: 0.0010
# Epoch 12/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0659 - mean_absolute_error: 0.2250 - val_loss: 0.0755 - val_mean_absolute_error: 0.2264 - learning_rate: 0.0010
# Epoch 13/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0675 - mean_absolute_error: 0.2276 - val_loss: 0.0734 - val_mean_absolute_error: 0.2210 - learning_rate: 0.0010
# Epoch 14/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0640 - mean_absolute_error: 0.2218 - val_loss: 0.0731 - val_mean_absolute_error: 0.2205 - learning_rate: 0.0010
# Epoch 15/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0657 - mean_absolute_error: 0.2255 - val_loss: 0.0749 - val_mean_absolute_error: 0.2258 - learning_rate: 0.0010
# Epoch 16/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0698 - mean_absolute_error: 0.2292 - val_loss: 0.0763 - val_mean_absolute_error: 0.2316 - learning_rate: 0.0010
# Epoch 17/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0681 - mean_absolute_error: 0.2284 - val_loss: 0.0752 - val_mean_absolute_error: 0.2229 - learning_rate: 0.0010
# Epoch 18/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0626 - mean_absolute_error: 0.2207 - val_loss: 0.0731 - val_mean_absolute_error: 0.2219 - learning_rate: 0.0010
# Epoch 19/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0642 - mean_absolute_error: 0.2220 - val_loss: 0.0760 - val_mean_absolute_error: 0.2271 - learning_rate: 5.0000e-04
# Epoch 20/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0620 - mean_absolute_error: 0.2186 - val_loss: 0.0762 - val_mean_absolute_error: 0.2244 - learning_rate: 5.0000e-04
# Epoch 21/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0626 - mean_absolute_error: 0.2209 - val_loss: 0.0757 - val_mean_absolute_error: 0.2291 - learning_rate: 5.0000e-04
# Epoch 22/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0584 - mean_absolute_error: 0.2141 - val_loss: 0.0795 - val_mean_absolute_error: 0.2326 - learning_rate: 5.0000e-04
# Epoch 23/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0626 - mean_absolute_error: 0.2191 - val_loss: 0.0771 - val_mean_absolute_error: 0.2281 - learning_rate: 2.5000e-04
# Epoch 24/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0580 - mean_absolute_error: 0.2156 - val_loss: 0.0753 - val_mean_absolute_error: 0.2262 - learning_rate: 2.5000e-04
# Epoch 25/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0612 - mean_absolute_error: 0.2188 - val_loss: 0.0783 - val_mean_absolute_error: 0.2302 - learning_rate: 2.5000e-04
# Epoch 26/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0601 - mean_absolute_error: 0.2163 - val_loss: 0.0792 - val_mean_absolute_error: 0.2308 - learning_rate: 2.5000e-04
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# /opt/conda/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /opt/conda/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# {'fold': 1, 'train_events': [np.int64(1), np.int64(2), np.int64(3), np.int64(5), np.int64(6), np.int64(7), np.int64(9), np.int64(10), np.int64(12), np.int64(13), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(29), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38)], 'val_events': [4, 11, 21], 'test_events': [8, 14, 28], 'N_train': 14528, 'N_val': 1362, 'N_test': 1362, 'RMSE_nT': 20.646358615901836, 'MAE_nT': 9.488999879246728, 'PICP_90': np.float64(0.9368575624082232), 'MPIW_90_nT': np.float64(50.61518544480023), 'PICP_95': np.float64(0.9508076358296622), 'MPIW_95_nT': np.float64(60.307454998059846)}
#                      event_no  DST_true   DST_pred   sigma_nT
# time
# 2000-05-15 07:30:00         8      16.0   5.420691  15.624462
# 2000-05-15 08:30:00         8       9.0  10.392397  15.624462
# 2000-05-15 09:30:00         8       9.0  11.265184  15.624462
# 2000-05-15 10:30:00         8       3.0   9.611659  15.624462
# 2000-05-15 11:30:00         8       1.0   2.153014  15.624462

# %%
print(type(df_events.index), df_events.index.dtype)
print(df_events.index[:5])
print(df_events.head())
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'> datetime64[ns, UTC]
# DatetimeIndex(['1998-04-24 05:30:00+00:00', '1998-04-24 06:30:00+00:00',
#                '1998-04-24 07:30:00+00:00', '1998-04-24 08:30:00+00:00',
#                '1998-04-24 09:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='time1', freq=None)
#                            bz_gsm      v  dst  event_no
# time1
# 1998-04-24 05:30:00+00:00    -6.7  444.0  -56         1
# 1998-04-24 06:30:00+00:00    -6.9  442.0  -59         1
# 1998-04-24 07:30:00+00:00    -4.4  435.0  -69         1
# 1998-04-24 08:30:00+00:00    -1.5  437.0  -50         1
# 1998-04-24 09:30:00+00:00    -4.0  452.0  -38         1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def plot_prediction_test_only(tp: pd.DataFrame, title="", z=1.96, freq="H"):
    """
    tp: DataFrame s indexom datetime (test set) a stĺpcami:
        DST_true, DST_pred, sigma_nT, (voliteľne) DST_persist
    Vykreslí iba dátumy z test sady a nerozťahuje čiary cez medzery medzi eventami.
    """
    if tp.empty:
        raise ValueError("tp je prázdne")

    tp = tp.sort_index()

    # vytvor plnú hodinovú os len v rozsahu test setu
    full_idx = pd.date_range(tp.index.min(), tp.index.max(), freq=freq, tz=tp.index.tz)
    g = tp.reindex(full_idx)

    lo = g["DST_pred"] - z * g["sigma_nT"]
    hi = g["DST_pred"] + z * g["sigma_nT"]

    plt.figure(figsize=(12,5))
    plt.plot(g.index, g["DST_true"], label="DST true")
    plt.plot(g.index, g["DST_pred"], label="LSTM+GP mean")
    plt.fill_between(g.index, lo, hi, alpha=0.2, label="95% interval")

    if "DST_persist" in g.columns:
        plt.plot(g.index, g["DST_persist"], label="Persistence")

    plt.legend()
    plt.title(title)
    plt.xlabel("Time")
    plt.ylabel("Dst (nT)")
    plt.tight_layout()
    plt.savefig("test") 
    plt.show()

# %%
for ev in sorted(tp["event_no"].unique()):
    g = tp[tp["event_no"] == ev]
    plot_prediction_test_only(g, title=f"Fold 1 – TEST event {ev} (L=24, H=4)")
# Out:
# /tmp/ipykernel_20485/2154247083.py:17: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_idx = pd.date_range(tp.index.min(), tp.index.max(), freq=freq, tz=tp.index.tz)
